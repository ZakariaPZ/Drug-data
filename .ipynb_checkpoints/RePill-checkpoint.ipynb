# %%
import pandas as pd

# %%
comp = pd.read_csv('allfiles-4/comp.txt', sep=",", header=None)

# %%
comp.rename(columns={
    0: "DRUG_CODE",
    1:"ACTIVE_INGREDIENT_CODE",
    2: "INGREDIENT",
    3: "INGREDIENT_SUPPLIED_IND",
    4: "STRENGTH",
    5: "STRENGTH_UNIT",
    6: "STRENGTH_TYPE",
    7: "DOSAGE_VALUE",
    8: "BASE",
    9: "DOSAGE_UNIT",
    10: "NOTES",
    11:"INGREDIENT_F",
    12: "STRENGTH_UNIT_F",
    13: "STRENGTH_TYPE_F",
    14: "DOSAGE_UNIT_F",
    15: 'NO NAME GIVEN',
    16: 'Province',
    17: "Country"
}, inplace=True)

# %%
comp.head()
# Out:
#    DRUG_CODE ACTIVE_INGREDIENT_CODE  INGREDIENT INGREDIENT_SUPPLIED_IND  \
# 0          9                  PIA08        8481       PALADIN LABS INC.
# 1         15                    NaN       14412           AA PHARMA INC
# 2         16                    NaN       14412           AA PHARMA INC
# 3         57                  ATL07        3659   LABORATOIRE ATLAS INC
# 4         68                  ATL07        3659   LABORATOIRE ATLAS INC
#
#     STRENGTH STRENGTH_UNIT STRENGTH_TYPE DOSAGE_VALUE BASE DOSAGE_UNIT  \
# 0  DIN OWNER             Y             Y            Y    N         NaN
# 1  DIN OWNER             Y             Y            Y  NaN      UNIT 1
# 2  DIN OWNER             Y             Y            Y  NaN      UNIT 1
# 3  DIN OWNER             Y             Y            Y    N         NaN
# 4  DIN OWNER             Y             Y            Y    N         NaN
#
#                               NOTES   INGREDIENT_F STRENGTH_UNIT_F  \
# ...

# %%
drug = pd.read_csv('allfiles-4/drug.txt', sep=",", header=None)

# %%
drug.rename(columns={
    0: "DRUG_CODE",
    1:"PRODUCT_CATEGORIZATION",
    2: "CLASS",
    3: "DRUG_IDENTIFICATION_NUMBER",
    4: "BRAND_NAME",
    5: "DESCRIPTOR",
    6: "PEDIATRIC_FLAG",
    7: "ACCESSION_NUMBER",
    8: "NUMBER_OF_AIS",
    9: "LAST_UPDATE_DATE",
    10: "AI_GROUP_NO",
    11:"CLASS_F",
    12: "BRAND_NAME_F",
    13: "DESCRIPTOR_F"
}, inplace=True)

# %%
drug.head()
# Out:
#    DRUG_CODE PRODUCT_CATEGORIZATION         CLASS  DRUG_IDENTIFICATION_NUMBER  \
# 0      10000                    NaN    Veterinary                      813761
# 1      10001                    NaN    Veterinary                      813826
# 2      10008                    NaN         Human                      644579
# 3      10009                    NaN         Human                      799823
# 4      10010                    NaN  Disinfectant                      804304
#
#                                      BRAND_NAME DESCRIPTOR PEDIATRIC_FLAG  \
# 0                                      LINCOMIX        NaN              N
# 1                                MGA 100 PREMIX        NaN              N
# 2                                    IMIPRAMINE        NaN              N
# 3  DIANEAL PD 101 CAPD SOLUTION W 2.5% DEXTROSE        NaN              N
# 4                                   OMNISAN LIQ        NaN              N
#
# ...

# %%
form = pd.read_csv('allfiles-4/form.txt', sep=",", header=None)

# %%
form.rename(columns={
    0: "DRUG_CODE",
    1:"PHARM_FORM_CODE",
    2: "PHARMACEUTICAL_FORM",
    3: "PHARMACEUTICAL_FORM_F"
}, inplace=True)

# %%
form.head()
# Out:
#    DRUG_CODE  PHARM_FORM_CODE  PHARMACEUTICAL_FORM     PHARMACEUTICAL_FORM_F
# 0      10000               56  POWDER FOR SOLUTION      Poudre pour solution
# 1      10001               24          DRUG PREMIX  Prémélange médicamenteux
# 2      10008               85               TABLET                  Comprimé
# 3      10009              134             SOLUTION                  Solution
# 4      10010               34               LIQUID                   Liquide

# %%
ingred = pd.read_csv('allfiles-4/ingred.txt', sep=",", header=None)

# %%
ingred.rename(columns={
    0: "DRUG_CODE",
    1:"ACTIVE_INGREDIENT_CODE",
    2: "INGREDIENT",
    3: "INGREDIENT_SUPPLIED_IND",
    4: "STRENGTH",
    5: "STRENGTH_UNIT",
    6: "STRENGTH_TYPE",
    7: "DOSAGE_VALUE",
    8: "BASE",
    9: "DOSAGE_UNIT",
    10: "NOTES",
    11: "INGREDIENT_F",
    12: "STRENGTH_UNIT_F",
    13: "STRENGTH_TYPE_F",
    14: "DOSAGE_UNIT_F"
}, inplace=True)

# %%
ingred.head()
# Out:
#    DRUG_CODE  ACTIVE_INGREDIENT_CODE  \
# 0      43063                     424
# 1      43041                   11085
# 2      42652                     150
# 3      46832                   16202
# 4      44090                    1241
#
#                                           INGREDIENT INGREDIENT_SUPPLIED_IND  \
# 0                                       AZITHROMYCIN                       I
# 1              DOBUTAMINE (DOBUTAMINE HYDROCHLORIDE)                       I
# 2                               ACETYLSALICYLIC ACID                       I
# 3  RABIES VACCINE INACTIVATED (HUMAN DIPLOID-CELL...                       I
# 4                             KETOROLAC TROMETHAMINE                       I
#
#    STRENGTH STRENGTH_UNIT  STRENGTH_TYPE  DOSAGE_VALUE BASE DOSAGE_UNIT  \
# 0     250.0            MG            NaN           NaN    N         NaN
# 1     250.0            MG            NaN          20.0    N          ML
# ...

# %%
package = pd.read_csv('allfiles-4/package.txt', sep=",", header=None)

# %%
package.rename(columns={
    0: "DRUG_CODE",
    1:"UPC",
    2: "PACKAGE_SIZE_UNIT",
    3: "PACKAGE_TYPE",
    4: "PACKAGE_SIZE",
    5: "PRODUCT_INFORMATION",
    6: "PACKAGE_SIZE_UNIT_F",
    7: "PACKAGE_TYPE_F"
}, inplace=True)

# %%
package.head(10)
# Out:
#    DRUG_CODE  UPC PACKAGE_SIZE_UNIT PACKAGE_TYPE  PACKAGE_SIZE  \
# 0          9  NaN               NaN          NaN           NaN
# 1         15  NaN               NaN          NaN           NaN
# 2         16  NaN               NaN          NaN           NaN
# 3         57  NaN               NaN          NaN           NaN
# 4         68  NaN               NaN          NaN           NaN
# 5         69  NaN               NaN          NaN           NaN
# 6         85  NaN               NaN          NaN           NaN
# 7         89  NaN               NaN          NaN           NaN
# 8        115  NaN               NaN          NaN           NaN
# 9        117  NaN               NaN          NaN           NaN
#
#     PRODUCT_INFORMATION  PACKAGE_SIZE_UNIT_F  PACKAGE_TYPE_F
# 0                   100                  NaN             NaN
# 1               100/500                  NaN             NaN
# 2               100/500                  NaN             NaN
# ...

# %%
package.isnull().sum()
# Out:
# DRUG_CODE                  0
# UPC                    11346
# PACKAGE_SIZE_UNIT      11328
# PACKAGE_TYPE           11326
# PACKAGE_SIZE           11328
# PRODUCT_INFORMATION        1
# PACKAGE_SIZE_UNIT_F    11347
# PACKAGE_TYPE_F         11347
# dtype: int64

# %%
package.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11347 entries, 0 to 11346
# Data columns (total 8 columns):
# DRUG_CODE              11347 non-null int64
# UPC                    1 non-null float64
# PACKAGE_SIZE_UNIT      19 non-null object
# PACKAGE_TYPE           21 non-null object
# PACKAGE_SIZE           19 non-null float64
# PRODUCT_INFORMATION    11346 non-null object
# PACKAGE_SIZE_UNIT_F    0 non-null float64
# PACKAGE_TYPE_F         0 non-null float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 709.3+ KB

# %% [markdown]
# Most columns are fill completely with null values.

# %%
pharm = pd.read_csv('allfiles-4/pharm.txt', sep=",", header=None)

# %%
pharm.rename(columns={
    0: "DRUG_CODE",
    1:"PHARMACEUTICAL_STD"
}, inplace=True)

# %%
pharm.head()
# Out:
#    DRUG_CODE PHARMACEUTICAL_STD
# 0       3132                USP
# 1       3133                USP
# 2       3141                USP
# 3          9                USP
# 4         15                USP

# %%
route = pd.read_csv('allfiles-4/route.txt', sep=",", header=None)

# %%
route.rename(columns={
    0: "DRUG_CODE",
    1:"ROUTE_OF_ADMINISTRATION_CODE",
    2: "ROUTE_OF_ADMINISTRATION",
    3: "ROUTE_OF_ADMINISTRATION_F"
}, inplace=True)

# %%
route.head()
# Out:
#    DRUG_CODE  ROUTE_OF_ADMINISTRATION_CODE  \
# 0      10000                            56
# 1      10001                            56
# 2      10008                            56
# 3      10009                             6
# 4      10010                             9
#
#                  ROUTE_OF_ADMINISTRATION  \
# 0                                   ORAL
# 1                                   ORAL
# 2                                   ORAL
# 3                               DIALYSIS
# 4  DISINFECTANT (Hospital/HC Facilities)
#
#                            ROUTE_OF_ADMINISTRATION_F
# 0                                              Orale
# 1                                              Orale
# 2                                              Orale
# 3                                            Dialyse
# 4  Désinfectant (Hôpitaux, établissements de soin...

# %%
schedule = pd.read_csv('allfiles-4/schedule.txt', sep=",", header=None)

# %%
schedule.rename(columns={
    0: "DRUG_CODE",
    1:"SCHEDULE",
    2: "SCHEDULE_F",
}, inplace=True)

# %%
schedule.head()
# Out:
#    DRUG_CODE      SCHEDULE           SCHEDULE_F
# 0      10000  Prescription         Prescription
# 1      10001           OTC       En vente libre
# 2      10008  Prescription         Prescription
# 3      10009       Ethical  Spécialité médicale
# 4      10010           OTC       En vente libre

# %%
status = pd.read_csv('allfiles-4/status.txt', sep=",", header=None)

# %%
status.rename(columns={
    0: "DRUG_CODE",
    1:"CURRENT_STATUS_FLAG",
    2: "STATUS",
    3: "HISTORY_DATE",
    4: "STATUS_F",
    5: "LOT_NUMBER",
    6: "EXPIRATION_DATE"
}, inplace=True)

# %%
status.head()
# Out:
#    DRUG_CODE CURRENT_STATUS_FLAG    STATUS HISTORY_DATE  STATUS_F LOT_NUMBER  \
# 0      10000                   N  APPROVED  02-MAR-2004  APPROUVÉ        NaN
# 1      10000                   N  APPROVED  08-FEB-2018  APPROUVÉ        NaN
# 2      10000                   N  APPROVED  15-MAY-1997  APPROUVÉ        NaN
# 3      10000                   N  APPROVED  24-FEB-2004  APPROUVÉ        NaN
# 4      10000                   N  APPROVED  27-JAN-2014  APPROUVÉ        NaN
#
#   EXPIRATION_DATE
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
ther = pd.read_csv('allfiles-4/ther.txt', sep=",", header=None)

# %%
ther.rename(columns={
    0: "DRUG_CODE",
    1:"TC_ATC_NUMBER",
    2: "TC_ATC",
    3: "TC_AHFS_NUMBER",
    4: "TC_AHFS",
    5: "TC_ATC_F",
    6: "TC_AHFS_F"
}, inplace=True)

# %%
ther.head()
# Out:
#    DRUG_CODE TC_ATC_NUMBER                          TC_ATC TC_AHFS_NUMBER  \
# 0          9       H03BB02                      THIAMAZOLE       68:36.08
# 1         15       N06AA10                   NORTRIPTYLINE    28:16.04.28
# 2         16       N06AA10                   NORTRIPTYLINE    28:16.04.28
# 3         57         D02AC  SOFT PARAFFIN AND FAT PRODUCTS       84:24.12
# 4         68       V04CG05                  METHYLTHIONINE       92:00.00
#
#                                              TC_AHFS  TC_ATC_F TC_AHFS_F
# 0                                 ANTITHYROID AGENTS       NaN       NaN
# 1  TRICYCLICS AND OTHER NOREPINEPHRINE-REUPTAKE I...       NaN       NaN
# 2  TRICYCLICS AND OTHER NOREPINEPHRINE-REUPTAKE I...       NaN       NaN
# 3                    BASIC OINTMENTS AND PROTECTANTS       NaN       NaN
# 4                   MISCELLANEOUS THERAPEUTIC AGENTS       NaN       NaN

# %%
vet = pd.read_csv('allfiles-4/vet.txt', sep=",", header=None)

# %%
vet.rename(columns={
    0: "DRUG_CODE",
    1:"VET_SPECIES",
    2: "VET_SUB_SPECIES",
    3: "VET_SPECIES_F"
}, inplace=True)

# %%
vet.head()
# Out:
#    DRUG_CODE   VET_SPECIES VET_SUB_SPECIES VET_SPECIES_F
# 0         85        CATTLE             NaN       Bétails
# 1         85  SWINE (PIGS)             NaN         Porcs
# 2         85         GOATS             NaN       Chèvres
# 3         85        HORSES             NaN      Cheveaux
# 4         85          CATS             NaN         Chats

# %%
comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12860 entries, 0 to 12859
# Data columns (total 18 columns):
# DRUG_CODE                  12860 non-null int64
# ACTIVE_INGREDIENT_CODE     5347 non-null object
# INGREDIENT                 12860 non-null int64
# INGREDIENT_SUPPLIED_IND    12860 non-null object
# STRENGTH                   12860 non-null object
# STRENGTH_UNIT              12860 non-null object
# STRENGTH_TYPE              12860 non-null object
# DOSAGE_VALUE               12860 non-null object
# BASE                       5821 non-null object
# DOSAGE_UNIT                1676 non-null object
# NOTES                      12858 non-null object
# INGREDIENT_F               12860 non-null object
# STRENGTH_UNIT_F            12860 non-null object
# STRENGTH_TYPE_F            12860 non-null object
# DOSAGE_UNIT_F              12838 non-null object
# 15                         304 non-null object
# 16                         12651 non-null object
# ...

# %%
dfs = [form, ingred, package, pharm, route, schedule, status, ther, vet]
database = comp.join(drug.set_index('DRUG_CODE'), on='DRUG_CODE', how='left')
for df in dfs:
    database = database.join(df.set_index('DRUG_CODE'), on='DRUG_CODE', how='left', lsuffix='_x')

# %%
database.head(1)
# Out:
#    DRUG_CODE ACTIVE_INGREDIENT_CODE_x  INGREDIENT_x INGREDIENT_SUPPLIED_IND_x  \
# 0          9                    PIA08          8481         PALADIN LABS INC.
#
#   STRENGTH_x STRENGTH_UNIT_x STRENGTH_TYPE_x DOSAGE_VALUE_x BASE_x  \
# 0  DIN OWNER               Y               Y              Y      N
#
#   DOSAGE_UNIT_x  ... EXPIRATION_DATE TC_ATC_NUMBER      TC_ATC TC_AHFS_NUMBER  \
# 0           NaN  ...             NaN       H03BB02  THIAMAZOLE       68:36.08
#
#               TC_AHFS TC_ATC_F TC_AHFS_F VET_SPECIES VET_SUB_SPECIES  \
# 0  ANTITHYROID AGENTS      NaN       NaN         NaN             NaN
#
#   VET_SPECIES_F
# 0           NaN
#
# [1 rows x 76 columns]

# %%
# shrunkDF = database[['DRUG_IDENTIFICATION_NUMBER', 'BRAND_NAME']]

# %%
# database[['DRUG_IDENTIFICATION_NUMBER', 'BRAND_NAME']]

# %%
database.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94076 entries, 0 to 12859
# Data columns (total 76 columns):
# DRUG_CODE                       94076 non-null int64
# ACTIVE_INGREDIENT_CODE_x        33706 non-null object
# INGREDIENT_x                    94076 non-null int64
# INGREDIENT_SUPPLIED_IND_x       94076 non-null object
# STRENGTH_x                      94076 non-null object
# STRENGTH_UNIT_x                 94076 non-null object
# STRENGTH_TYPE_x                 94076 non-null object
# DOSAGE_VALUE_x                  94076 non-null object
# BASE_x                          39016 non-null object
# DOSAGE_UNIT_x                   9449 non-null object
# NOTES_x                         94057 non-null object
# INGREDIENT_F_x                  94076 non-null object
# STRENGTH_UNIT_F_x               94076 non-null object
# STRENGTH_TYPE_F_x               94076 non-null object
# DOSAGE_UNIT_F_x                 93894 non-null object
# ...
